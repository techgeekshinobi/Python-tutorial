# %%
for i in range(6):   #n  
    for j in range(i+1):    #n*n
        print('*',end='')
    print()    

    #O(n^2)--->worst time complexity
# Out:
# *
# **
# ***
# ****
# *****
# ******

# %%
for i in range(1,7): print("*"*i)
#time complexity is O(n)
# Out:
# *
# **
# ***
# ****
# *****
# ******
