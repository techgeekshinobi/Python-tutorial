# %% [markdown]
# 1. for
# 2. while
# 3. nested
# 4. Loop control statements: break, continue, pass

# %%
cnt=0
while(cnt<5):
    cnt=cnt+1
    print("hello hi")
# Out:
# hello hi
# hello hi
# hello hi
# hello hi
# hello hi

# %%
from __future__ import print_function
for i in range(1,5):
    for j in range(i):
        print(i,end=' ')
    print()
# Out:
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %% [markdown]
# # Loop control statements

# %%
#continue---> skip the current iteration of a loop and move to the next iteration
for chars in "character":
    if chars=="e" or chars=="r" or chars=="a":
        continue
    print(chars)
# Out:
# c
# h
# c
# t
