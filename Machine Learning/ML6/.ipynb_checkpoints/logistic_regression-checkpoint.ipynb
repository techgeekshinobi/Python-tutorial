# %% [markdown]
# ## Logistic regression using Binary Classifier

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 8    62
# 0    22
# 21   26
# 15   55
# 5    56
# 10   18

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 8    62
# 0    22
# 21   26
# 15   55
# 5    56
# 10   18

# %% [markdown]
# model.coef_ indicates value of m in y=mx+b

# %%
model.coef_
# Out:
# array([[0.11557954]])

# %% [markdown]
# model.intercept_ indicates value of b in y=mx+b

# %%
model.intercept_
# Out:
# array([-4.45150419])

# %% [markdown]
# Lets define a sigmoid function and do the math

# %%
import math
def sigmoid(x):
    return 1/(1+math.exp(-x))

# %%
def prediction_function(age):
    z=0.112*age-4.45
    y=sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.370516888032605

# %%
age=43
prediction_function(age)
# Out:
# 0.5904920849765638
