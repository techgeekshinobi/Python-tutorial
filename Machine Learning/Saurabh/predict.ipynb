# %%
import pandas as pd
df=pd.read_excel("Saurabh_Test_Data.xlsx")
df.head()
# Out:
#   Owning Subsidiary (Marketing Project) (Marketing Project)   Task ID  \
# 0                                          Australia         ST789891
# 1                                          Australia         ST789922
# 2                                          Australia         ST791779
# 3                                          Australia         ST791834
# 4                                          Australia         ST791971
#
#         Active Stage        Service Type  \
# 0  Additional Review  Targeted List Pull
# 1  Additional Review  Targeted List Pull
# 2  Additional Review  Targeted List Pull
# 3  Additional Review  Targeted List Pull
# 4              Build  Targeted List Pull
#
#   Audience (Marketing Project) (Marketing Project)          Created On  \
# 0                                       Commercial 2023-01-15 18:33:43
# 1                                       Commercial 2023-01-15 20:34:04
# 2                                       Commercial 2023-01-17 18:04:34
# ...

# %%
df['Created On'] = pd.to_datetime(df['Created On'], errors='coerce')

# %%
type(df['Created On'])
# Out:
# pandas.core.series.Series

# %%
df['Created On'] = pd.to_datetime(df['Created On'].dt.date)

# %%
df.head()
# Out:
#   Owning Subsidiary (Marketing Project) (Marketing Project)   Task ID  \
# 0                                          Australia         ST789891
# 1                                          Australia         ST789922
# 2                                          Australia         ST791779
# 3                                          Australia         ST791834
# 4                                          Australia         ST791971
#
#         Active Stage        Service Type  \
# 0  Additional Review  Targeted List Pull
# 1  Additional Review  Targeted List Pull
# 2  Additional Review  Targeted List Pull
# 3  Additional Review  Targeted List Pull
# 4              Build  Targeted List Pull
#
#   Audience (Marketing Project) (Marketing Project) Created On  \
# 0                                       Commercial 2023-01-15
# 1                                       Commercial 2023-01-15
# 2                                       Commercial 2023-01-17
# ...

# %%
df['Created On'].iloc[0]
# Out:
# Timestamp('2023-01-15 00:00:00')

# %%
df1=df.groupby(df['Created On'])

# %%
df1
